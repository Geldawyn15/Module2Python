# %% [markdown]
# ## Step 1
# Ecrire une fonction main, qui renvoie comme valeur de retour un int.
# a fonction doit afficher dans la console : « Bienvenue dans le jeu de la dichotomie ! » et fermer le
# programme.

# %%
#Step 1
def main(): 
    print("Bienvenue dans le jeu de la dichotomie !")
    return 1

main()

# %% [markdown]
# ## Step 2
# Dans la fonction main, récupérer le nom du joueur dans une variable userName, qu’il rentrera
# directement en console avec un commentaire

# %%
#Step 2
def main(): 
    userName = input("Quel est votre nom : ")
    print("Bienvenue dans le jeu de la dichotomie "+userName+"!")
    
    return 1

main()

# %% [markdown]
# ## Step 3
# Donner les instructions du jeu en mettant en variable le nombre minimum et maximum.
# Exemple « Paul pense à un nombre entre 0 et 100 » où 0 est la valeur de la variable minValue et 100
# est la valeur de la variable maxValue.
# Pourquoi ne peut-on pas mettre la variable directement dans la fonction print ?

# %%
#Step 3

def main():
    userName = input("Quel est ton nom : ")
    minValue = 1
    maxValue = 100
    
    print("Hello "+ userName +", pensez à un nombre entre "+str(minValue)+" et "+str(maxValue)+" ")
    
main()

# %% [markdown]
# ## Step 4
# Maintenant créer une structure itérative avec les conditions nécessaires pour deviner le nombre par
# la méthode de « dichotomie ».
# N’oubliez pas d’initialiser un compteur et l’utiliser pour compter le nombre de fois nécessaire pour
# trouver le bon nombre.
# Quel type de boucle est la plus adaptée ?
# Si la réponse est bonne le jeu doit s’arrête

# %%
#Step 5 V1.0
# programe pour joue a un jeux de devinette 

def main():
    def dichotomie(minValue, maxValue):
        """Asks questions about your number and returns how many questions it takes to guess your number
        """
        #metre a zero les variables num_status et question_amt
        num_status = ""
        question_amt = 0
        while num_status != "=":
            
            # formule pour prendre le numero au millieux du minValue et maxValue
            dichotValue =  int(minValue) + (int(maxValue) - int(minValue))/2
            #converti le variable 'dichotValue' en int au cas où il est un float
            
            
            dichotValue = int(dichotValue)
            # input utilisatuer qui verifie si le numero de l'utilisateur est plus, moins au egale au 
            num_status = input("Est-ce votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
                
            #counter pour combien de questions etait demande
            question_amt += 1
            
            if num_status == "+":
                minValue = dichotValue 
            elif num_status == "-":
                maxValue = dichotValue 
            elif num_status == "=":
                return "Your number Was "+ str(dichotValue) +"! I found it in "+ str(question_amt) + " questions !"
    
    
    userName = input("Quel est ton nom : ")
    minValue = 0
    maxValue = 100
    
    print("Hello "+ userName +", pensez à un nombre entre "+str(minValue)+" et "+str(maxValue)+" ")
    print(dichotomie(minValue,maxValue))

# %% [markdown]
# ## Step 5
# Pour finir en sortant de la boucle, il faut afficher un compte rendu qui contient le nombre deviné et le
# nombre de questions posées pour trouver et un message de sortie

# %%
#Step 5 V1.1 
# programe pour joue a un jeux de devinette 

def main():
    def dichotomie(minValue, maxValue):
        """Asks questions about your number and returns how many questions it takes to guess your number
        """
        #metre a zero les variables num_status et question_amt
        num_status = ""
        question_amt = 0
        verif = ['+','-','=']
        while num_status != "=":
            
            # formule pour prendre le numero au millieux du minValue et maxValue
            dichotValue =  int(minValue) + (int(maxValue) - int(minValue))/2
            
            #converti le variable 'dichotValue' en int au cas où il est un float
            dichotValue = int(dichotValue)
            if int(dichotValue) == 99 and minValue == 99:
                return "Vote numero est 100! J'ai trouvé en "+ str(question_amt) + " questions !"
            
            
            # input utilisatuer qui verifie si le numero de l'utilisateur est plus, moins au egale au 
            num_status = input("Est-ce votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
            
            #boucle pour vérifier si le caractère saisie par l'utilisateur est l'un des trois demandé
            while num_status not in verif:
                print("Merci de rentre que l'un des caractères suivants + ou - ou =  ")
                num_status = input("Est-ce votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
                
            #counter pour combien de questions etait demande
            question_amt += 1
            
            if num_status == "+":
                minValue = dichotValue 
            elif num_status == "-":
                maxValue = dichotValue 
            elif num_status == "=":
                return "Your number Was "+ str(dichotValue) +"! I found it in "+ str(question_amt) + " questions !"
    
    
    userName = input("Quel est ton nom : ")
    minValue = 0
    maxValue = 100
    
    print("Hello "+ userName +", pensez à un nombre entre "+str(minValue)+" et "+str(maxValue)+" ")
    print(dichotomie(minValue,maxValue))
    
    
main()

# %%
#Step 6 V1.2 refactorisation du code et changement de algorithme de verification du value devinées
def dichotomie(minValue, maxValue):
        """Asks questions about your number and returns how many questions it takes to guess your number
        """
        #metre a zero les variables num_status et question_amt
        num_status = ""
        question_amt = 0
        verif = ['+','-','=']
        while num_status != "=":
            
            # formule pour prendre le numero au millieux du minValue et maxValue
            dichotValue =  int(minValue) + (int(maxValue) - int(minValue))/2
            
            #converti le variable 'dichotValue' en int au cas où il est un float
            dichotValue = int(dichotValue)
            if int(dichotValue) == minValue and minValue == int(maxValue) - 1:
                return "Votre numero est "+str(maxValue)+"! J'ai trouvé en "+ str(question_amt) + " questions !"
            
            
            # input utilisatuer qui verifie si le numero de l'utilisateur est plus, moins au egale au 
            num_status = input("Est-ce votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
            
            #boucle pour vérifier si le caractère saisie par l'utilisateur est l'un des trois demandé
            while num_status not in verif:
                print("Merci de rentre que l'un des caractères suivants + ou - ou =  ")
                num_status = input("Est-ce que votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
                
            #counter pour combien de questions etait demande
            question_amt += 1
            
            if num_status == "+":
                minValue = dichotValue 
            elif num_status == "-":
                maxValue = dichotValue 
            elif num_status == "=":
                return "Votre numero est "+ str(dichotValue) +"! J'ai trouvé en "+ str(question_amt) + " questions !"

def main():
    
    #demandez à l'utilisateur son nom, le numero minimum est maximum
    userName = input("Quel est ton nom : ")
    minValue = input("Entrez le valeur Maximale: ")
    maxValue = input("Entrez le valeur Maximale: ")
    
    print("Hello "+ userName +", pensez à un nombre entre "+str(minValue)+" et "+str(maxValue)+" ")
    print(dichotomie(minValue,maxValue))
    print("Merci davoir joue "+userName)
    
    
main()

# %%
#Step 6 V1.3 Rajoute un function pour valide que les input minValue et maxValue sont des entiers
def validate_input(input_str):
    """Valide que l'entrée est un entier valide."""
    try:
        return int(input_str)
    except ValueError:
        return validate_input(input("Entrée invalide. Veuillez saisir un entier valide : "))

def dichotomie(minValue, maxValue):
    """Asks questions about your number and returns how many questions it takes to guess your number"""
    num_status = ""
    question_amt = 0
    verif = ['+','-','=']
    
    while num_status != "=":
        # formule pour prendre le numero au millieux du minValue et maxValue
        dichotValue =  minValue + (maxValue - minValue)/2
        
        #converti le variable 'dichotValue' en int au cas où il est un float
        dichotValue = int(dichotValue)
        
        if int(dichotValue) == minValue and minValue == int(maxValue) - 1:
            return "Votre numero est "+str(maxValue)+"! J'ai trouvé en "+ str(question_amt) + " questions !"
        
        # input utilisatuer qui verifie si le numero de l'utilisateur est plus, moins au egale au 
        num_status = input("Est-ce votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
        
        #boucle pour vérifier si le caractère saisie par l'utilisateur est l'un des trois demandé
        while num_status not in verif:
            print("Merci de rentre que l'un des caractères suivants + ou - ou =  ")
            num_status = input("Est-ce que votre nombre est plus grand, plus petit ou égal à "+ str(dichotValue)+"? [+/-/=]")
            
        #counter pour combien de questions etait demande
        question_amt += 1
        
        if num_status == "+":
            minValue = dichotValue 
        elif num_status == "-":
            maxValue = dichotValue 

    return "Votre numero est "+ str(dichotValue) +"! J'ai trouvé en "+ str(question_amt) + " questions !"

def main():
    
    #demandez à l'utilisateur son nom, le numero minimum est maximum
    userName = input("Quel est ton nom : ")
    minValue = validate_input(input("Entrez le valeur Minimum: "))
    maxValue = validate_input(input("Entrez le valeur Maximum: "))
    
    print("Hello "+ userName +", pensez à un nombre entre "+str(minValue)+" et "+str(maxValue)+" ")
    print(dichotomie(minValue,maxValue))
    print("Merci davoir joue "+userName)
    
main()
